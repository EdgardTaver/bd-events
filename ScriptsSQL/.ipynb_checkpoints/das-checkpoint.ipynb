# %%
import random

def random_number_of_size(n):
    sequence = ""
    
    while len(sequence) < n:
        random_num = random.randint(0,9)
        sequence += str(random_num)
    
    return sequence

random_number_of_size(10)
# Out:
# '1812357977'

# %%
n = 0

while n < 15:
    s = random_number_of_size(33)
    print(s)
    n += 1
# Out:
# 219764790983923211561489984452293
# 426084381510412885642274554266225
# 006280658979781637373161577615530
# 644008433860468415714138600170149
# 717739920869270189870366212011774
# 449980985927099111652710621802460
# 501308896170228763726874425956636
# 084205141340997807569697448578550
# 309112754348759670371282393623435
# 030689556318022253787444216673350
# 815351489792185287563473399170757
# 718637398634936091572837982399913
# 152413995515345958655679842862859
# 188641950888826080533009927897881
# 539928100406615913273177623894569

# %%
def random_phone():
    sequence = "("
    
    sequence += str(random.randint(0,9))
    sequence += str(random.randint(0,9))
    
    sequence += ")9"
    
    n = 0
    while n < 4:
        sequence += str(random.randint(0,9))
        n += 1
        
    sequence += "-"
    
    n = 0
    while n < 4:
        sequence += str(random.randint(0,9))
        n += 1
    
    return sequence

n = 0
while n < 30:
    s = random_phone()
    print(s)
    n += 1
# Out:
# (85)97918-7544
# (04)90662-7139
# (73)98284-3079
# (86)90665-4615
# (83)98826-1354
# (78)97574-3067
# (83)92968-1813
# (86)92354-1322
# (26)95219-0312
# (63)91795-5308
# (44)92186-9269
# (73)98045-6361
# (57)93979-3717
# (89)94042-5608
# (45)92533-8656
# (81)93180-7125
# (79)94669-1475
# (22)97384-1303
# (45)98271-1446
# (06)92531-6665
# (04)98609-4049
# (69)91173-9646
# (66)99277-6521
# (22)94855-7956
# (55)99731-6896
# (50)96638-4283
# (69)95030-6630
# (05)97197-3222
# (48)98420-4144
# (18)91468-3258
